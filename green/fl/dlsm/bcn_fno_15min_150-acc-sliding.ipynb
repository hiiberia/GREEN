# %% [markdown]
# # FNO - Barcelona - 15min-150-Acc-Sliding

# %%
import os
#Plot imports
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score 
import seaborn as sns

# %%
from FNO import FNO

# %%
# To show the logs
import logging
logging.getLogger().addHandler(logging.StreamHandler())

# %%
input_names = ['E']

# %%
output_names = ['E_shifted']

# %%
# Create a dict with the chanels as values and name variables as keys
inputs = {}
for input_name in input_names:
    inputs[input_name] = 1
    
outputs = {}
for output_name in output_names:
    outputs[output_name] = 1

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO

# %%
#Config file for the model
config_path = ("./experiments/confs/")
config_name ="conf.yaml"

# %%
#Datasets
inputs = inputs
outputs = outputs

# %%
main_path = '../data/bcn-temp-rain-weekday-month-hour-15min-150-acc-sliding/'
train_path = main_path + 'muvacas_pred_target5step_train.hdf5'
test_path = main_path + 'muvacas_pred_target5step_test.hdf5'
statistics_path = main_path + 'statistics_pt5step_train.csv'

# %%
mode = 'direct'

# %%
output_path = './experiments/experiment_92/output/'

# %%
FNO_model = FNO(config_path = config_path,
                      config_name = config_name, 
                      inputs = inputs,
                      outputs = outputs,
                      train_path = train_path,
                      test_path = test_path,
                      statistics_path= statistics_path,
                      mode= mode,
                      output_path=output_path)
# Out:
# /opt/conda/lib/python3.8/site-packages/modulus/sym/hydra/utils.py:148: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(
# Setting JobRuntime:name=app
# Setting JobRuntime:name=app
# TorchScript default is being turned off due to PyTorch version mismatch.
# TorchScript default is being turned off due to PyTorch version mismatch.

# %%
FNO_model.compute_model()
# Out:
# loaded: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/../data/bcn-temp-rain-weekday-month-hour-15min-150-acc-sliding/muvacas_pred_target5step_train.hdf5
# avaliable keys: ['DiaSemana_0', 'DiaSemana_1', 'DiaSemana_2', 'DiaSemana_3', 'DiaSemana_4', 'DiaSemana_5', 'DiaSemana_6', 'E', 'E_shifted', 'Hora_0', 'Hora_1', 'Hora_10', 'Hora_11', 'Hora_12', 'Hora_13', 'Hora_14', 'Hora_15', 'Hora_16', 'Hora_17', 'Hora_18', 'Hora_19', 'Hora_2', 'Hora_20', 'Hora_21', 'Hora_22', 'Hora_23', 'Hora_3', 'Hora_4', 'Hora_5', 'Hora_6', 'Hora_7', 'Hora_8', 'Hora_9', 'Mes_1', 'Mes_10', 'Mes_11', 'Mes_12', 'Mes_2', 'Mes_3', 'Mes_4', 'Mes_5', 'Mes_6', 'Mes_7', 'Mes_8', 'Mes_9', 'Rain', 'Temp']
# loaded: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/../data/bcn-temp-rain-weekday-month-hour-15min-150-acc-sliding/muvacas_pred_target5step_test.hdf5
# avaliable keys: ['DiaSemana_0', 'DiaSemana_1', 'DiaSemana_2', 'DiaSemana_3', 'DiaSemana_4', 'DiaSemana_5', 'DiaSemana_6', 'E', 'E_shifted', 'Hora_0', 'Hora_1', 'Hora_10', 'Hora_11', 'Hora_12', 'Hora_13', 'Hora_14', 'Hora_15', 'Hora_16', 'Hora_17', 'Hora_18', 'Hora_19', 'Hora_2', 'Hora_20', 'Hora_21', 'Hora_22', 'Hora_23', 'Hora_3', 'Hora_4', 'Hora_5', 'Hora_6', 'Hora_7', 'Hora_8', 'Hora_9', 'Mes_1', 'Mes_10', 'Mes_11', 'Mes_12', 'Mes_2', 'Mes_3', 'Mes_4', 'Mes_5', 'Mes_6', 'Mes_7', 'Mes_8', 'Mes_9', 'Rain', 'Temp']
# Arch <class 'modulus.sym.models.fno.FNOArch'> currently does not support FuncArch
# Arch <class 'modulus.sym.models.fno.FNOArch'> currently does not support FuncArch
# Arch <class 'modulus.sym.models.fno.FNOArch'> currently does not support FuncArch
# Arch <class 'modulus.sym.models.fno.FNOArch'> currently does not support FuncArch
# E: (27023, 1, 150)
# E_shifted: (27023, 1, 150)
# E: (4213, 1, 150)
# E_shifted: (4213, 1, 150)

# %%
FNO_model.solve()
# Out:
# Installed PyTorch version 2.2.1+cu121 is not TorchScript supported in Modulus. Version 2.1.0a0+4136153 is officially supported.
# Installed PyTorch version 2.2.1+cu121 is not TorchScript supported in Modulus. Version 2.1.0a0+4136153 is officially supported.
# attempting to restore from: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output
# attempting to restore from: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output
# Success loading optimizer: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/optim_checkpoint.0.pth
# Success loading optimizer: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/optim_checkpoint.0.pth
# Success loading model: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/fno.0.pth
# Success loading model: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/fno.0.pth
# [step:      50000] saved constraint results to ./experiments/experiment_92/output/
# [step:      50000] saved constraint results to ./experiments/experiment_92/output/
# [step:      50000] record constraint batch time:  1.439e-02s
# [step:      50000] record constraint batch time:  1.439e-02s
# [step:      50000] saved validator results to ./experiments/experiment_92/output/
# [step:      50000] saved validator results to ./experiments/experiment_92/output/
# [step:      50000] record validators time:  2.378e+00s
# [step:      50000] record validators time:  2.378e+00s
# [step:      50000] saved checkpoint to /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output
# [step:      50000] saved checkpoint to /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output
# [step:      50000] loss:  9.644e+07
# [step:      50000] loss:  9.644e+07
# [step:      50000] reached maximum training steps, finished training!
# [step:      50000] reached maximum training steps, finished training!

# %%
FNO_model.evaluate()
# Out:
# Success loading model: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/fno.0.pth
# Success loading model: /home/jovyan/nas/adorado/green/green/fl/DLSM/FNO/experiments/experiment_92/output/fno.0.pth
# [step:      50000] saved validator results to ./experiments/experiment_92/output/
# [step:      50000] saved validator results to ./experiments/experiment_92/output/
# [step:      50000] record validators time:  2.979e+00s
# [step:      50000] record validators time:  2.979e+00s

# %%
import matplotlib.pyplot as plt

cmap = plt.cm.viridis

# %%
data = np.load(output_path + "/validators/test.npz", allow_pickle=True)
data

# %%
data = np.atleast_1d(data.f.arr_0)[0]

# %%
data['pred_E_shifted'][0]
# Out:
# array([[ 8.53910312e+04,  9.00066797e+04,  9.82701406e+04,
#          9.99424844e+04,  9.99136016e+04,  9.85769219e+04,
#          9.90728594e+04,  9.77940312e+04,  9.27169844e+04,
#          9.62793984e+04,  1.01453562e+05,  1.06841625e+05,
#          1.03190406e+05,  9.93958594e+04,  9.90070469e+04,
#          9.06250000e-01, -7.50000000e+00, -9.69921875e+00,
#         -1.24687500e+01, -2.18281250e+01, -5.87109375e+00,
#         -4.22265625e+00, -1.15546875e+01,  2.92539062e+01,
#          1.94175781e+02,  6.62191406e+02,  7.23945312e+02,
#          1.18925391e+03,  1.18153125e+03,  1.14823828e+03,
#          8.20710938e+02,  2.66726562e+02,  8.00625000e+01,
#          4.90765625e+02,  1.48088672e+03,  8.89597656e+02,
#          4.14703125e+02,  4.42929688e+01, -1.06718750e+01,
#         -6.40625000e+00, -8.65625000e+00, -1.43476562e+01,
#          1.88683594e+02,  1.27959766e+03,  3.03218359e+03,
#          3.48930859e+03,  4.93452344e+03,  7.46680078e+03,
#          1.03254648e+04,  1.24133555e+04,  1.40941055e+04,
#          1.54890352e+04,  1.78138086e+04,  1.98944141e+04,
#          1.96240117e+04,  1.79241875e+04,  1.73314023e+04,
#          2.00435234e+04,  2.23184062e+04,  2.71264941e+04,
#          3.34193750e+04,  3.63149805e+04,  3.98229219e+04,
#          4.30216406e+04,  4.44285078e+04,  4.36684141e+04,
#          4.25066953e+04,  4.40393555e+04,  4.84033125e+04,
#          5.26406367e+04,  5.40211914e+04,  5.52043281e+04,
#          5.51147734e+04,  5.61240820e+04,  5.84042109e+04,
#          5.92621562e+04,  6.04483789e+04,  6.16098398e+04,
#          6.42516523e+04,  6.48242266e+04,  6.52860781e+04,
#          6.70807422e+04,  7.01386562e+04,  7.30623125e+04,
#          7.76251875e+04,  7.98321016e+04,  7.98679844e+04,
#          8.15528125e+04,  8.55793906e+04,  8.76714766e+04,
#          9.61027812e+04,  9.90490625e+04,  9.50414688e+04,
#          8.72064922e+04,  8.54310547e+04,  8.66381641e+04,
#          8.21586953e+04,  8.10906250e+04,  8.30472578e+04,
#          8.68392656e+04,  9.20212188e+04,  9.86217812e+04,
#          9.91199844e+04,  9.69418828e+04,  9.81161641e+04,
#          9.92363281e+04,  9.53958438e+04,  9.45881094e+04,
#          9.27043906e+04,  9.77442656e+04,  9.72856484e+04,
#         -4.81640625e+00,  9.88671875e+00,  9.44921875e+00,
#          2.18750000e-01, -1.73945312e+01, -5.07812500e+00,
#          3.47187500e+01,  1.00621094e+02,  3.89226562e+02,
#          3.63511719e+02,  1.91613281e+02,  9.09375000e+01,
#          3.10636719e+02,  1.01066797e+03,  2.76122266e+03,
#          3.23983203e+03,  2.48775781e+03,  6.00101562e+02,
#          8.93398438e+01, -5.51562500e+00, -8.71484375e+00,
#         -1.71757812e+01,  2.48789062e+01,  2.35964844e+02,
#          9.65199219e+02,  3.17777734e+03,  5.10676953e+03,
#          4.16743750e+03,  2.18850781e+03,  1.97007812e+03,
#          4.34305469e+03,  8.33531250e+03,  1.19236562e+04,
#          1.73610195e+04,  2.28190801e+04,  2.31779023e+04,
#          2.08366367e+04,  1.85360312e+04,  1.69063320e+04]], dtype=float32)

# %%
# Ajustando el número de filas considerando que tenemos 11 índices y queremos 2 columnas
n_rows = (30 + 1) // 2
n_cols = 3

# %%
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 4 * n_rows))
fig.tight_layout(pad=4.0)

for i in range(30):
    row = i // n_cols
    col = i % n_cols
    ax = axes[row, col]
    
    # Asumiendo que cada array tiene la misma longitud y queremos graficar todos los valores
    array_length = len(data['pred_E_shifted'][i*50][0])
    ax.plot(range(array_length), data['pred_E_shifted'][i*50][0], label='Predicted', marker='.', color='orange')
    ax.plot(range(array_length), data['true_E_shifted'][i*50][0], label='True', marker='.', color='green')
    ax.set_title(f'Index {i}')
    ax.legend()

# Si el número total de subplots no es un múltiplo exacto de n_cols, ocultamos los subplots adicionales
if n_rows * n_cols > 11:
    for j in range(i+1, n_rows * n_cols):
        row = j // n_cols
        col = j % n_cols
        axes[row, col].axis('off')

plt.show()
# Out:
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/opt/conda/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/opt/conda/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %%
import imageio
import os

step_size = 1
n_samples = 300 * 5

dir_name = 'bcn-15min-150-acc-sliding'

# Verifica si el directorio existe. Si no, lo crea
if not os.path.exists(f'frames/{dir_name}/'):
    os.makedirs(f'frames/{dir_name}/')
                
if not os.path.exists(f'gifs/{dir_name}/'):
    os.makedirs(f'gifs/{dir_name}/')

# Genera y guarda cada subplot como una imagen
for i in range(n_samples):
    if i%10 == 0: print(f'Iter: {i}')
    fig, ax = plt.subplots(figsize=(18, 4))
    array_length = len(data['pred_E_shifted'][i*step_size][0])
    ax.plot(range(array_length), data['pred_E_shifted'][i*step_size][0], label='Predicted', marker='.', color='orange')
    ax.plot(range(array_length), data['true_E_shifted'][i*step_size][0], label='True', marker='.', color='green')
    ax.set_title(f'Index {i}')
    ax.legend()
    ax.set_ylim(-10, 300000)  # Establece los límites en el eje y
    plt.savefig(f'frames/{dir_name}/frame_{i}.png')  # Guarda la figura
    plt.close()  # Cierra la figura actual para liberar memoria

# Lista para almacenar las direcciones de las imágenes
filenames = [f'frames/{dir_name}/frame_{i}.png' for i in range(n_samples)]

# Crear el GIF
with imageio.get_writer(f'gifs/{dir_name}/my_plots.gif', mode='I', fps=60) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
# Out:
# Iter: 0
# Iter: 10
# Iter: 20
# Iter: 30
# Iter: 40
# Iter: 50
# Iter: 60
# Iter: 70
# Iter: 80
# Iter: 90
# Iter: 100
# Iter: 110
# Iter: 120
# Iter: 130
# Iter: 140
# Iter: 150
# Iter: 160
# Iter: 170
# Iter: 180
# Iter: 190
# Iter: 200
# Iter: 210
# Iter: 220
# Iter: 230
# Iter: 240
# Iter: 250
# Iter: 260
# Iter: 270
# Iter: 280
# Iter: 290
# Iter: 300
# Iter: 310
# Iter: 320
# Iter: 330
# Iter: 340
# Iter: 350
# Iter: 360
# Iter: 370
# Iter: 380
# Iter: 390
# Iter: 400
# Iter: 410
# Iter: 420
# Iter: 430
# Iter: 440
# Iter: 450
# Iter: 460
# Iter: 470
# Iter: 480
# Iter: 490
# Iter: 500
# Iter: 510
# Iter: 520
# Iter: 530
# Iter: 540
# Iter: 550
# Iter: 560
# Iter: 570
# Iter: 580
# Iter: 590
# Iter: 600
# Iter: 610
# Iter: 620
# Iter: 630
# Iter: 640
# Iter: 650
# Iter: 660
# Iter: 670
# Iter: 680
# Iter: 690
# Iter: 700
# Iter: 710
# Iter: 720
# Iter: 730
# Iter: 740
# Iter: 750
# Iter: 760
# Iter: 770
# Iter: 780
# Iter: 790
# Iter: 800
# Iter: 810
# Iter: 820
# Iter: 830
# Iter: 840
# Iter: 850
# Iter: 860
# Iter: 870
# Iter: 880
# Iter: 890
# Iter: 900
# Iter: 910
# Iter: 920
# Iter: 930
# Iter: 940
# Iter: 950
# Iter: 960
# Iter: 970
# Iter: 980
# Iter: 990
# Iter: 1000
# Iter: 1010
# Iter: 1020
# Iter: 1030
# Iter: 1040
# Iter: 1050
# Iter: 1060
# Iter: 1070
# Iter: 1080
# Iter: 1090
# Iter: 1100
# Iter: 1110
# Iter: 1120
# Iter: 1130
# Iter: 1140
# Iter: 1150
# Iter: 1160
# Iter: 1170
# Iter: 1180
# Iter: 1190
# Iter: 1200
# Iter: 1210
# Iter: 1220
# Iter: 1230
# Iter: 1240
# Iter: 1250
# Iter: 1260
# Iter: 1270
# Iter: 1280
# Iter: 1290
# Iter: 1300
# Iter: 1310
# Iter: 1320
# Iter: 1330
# Iter: 1340
# Iter: 1350
# Iter: 1360
# Iter: 1370
# Iter: 1380
# Iter: 1390
# Iter: 1400
# Iter: 1410
# Iter: 1420
# Iter: 1430
# Iter: 1440
# Iter: 1450
# Iter: 1460
# Iter: 1470
# Iter: 1480
# Iter: 1490
# /tmp/ipykernel_51745/3035404027.py:35: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39872
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39792
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39747
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39793
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39722
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39739
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39726
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39496
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39821
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39590
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39586
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39402
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39654
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39618
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39155
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37277
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37269
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36995
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37420
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37317
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37675
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37673
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38283
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38521
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38761
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38677
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39207
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38957
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39013
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39052
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39296
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39328
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39648
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39921
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39924
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40132
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40417
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40523
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40833
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40891
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40478
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40566
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40524
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41058
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41098
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41384
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41560
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41817
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42044
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42156
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42205
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42248
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42432
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42587
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42379
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42446
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42621
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42180
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44628
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44313
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44157
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43752
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43839
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43809
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43533
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43305
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43080
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43001
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43100
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42979
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42446
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42123
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42116
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42047
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41631
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41591
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41606
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41373
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41374
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41360
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41715
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41347
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41616
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41509
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41450
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41519
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41545
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41561
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41458
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41359
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41387
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40972
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41144
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41163
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40905
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40737
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40911
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40323
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40685
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40296
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40306
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39908
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40058
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40210
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39972
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39935
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40099
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40095
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40093
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40148
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40187
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38599
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38852
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39031
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39474
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39805
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40092
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40447
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40927
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40818
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41010
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40719
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40979
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41192
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41226
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41666
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41728
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42103
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42179
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42424
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42300
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42273
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42228
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42529
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42312
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42609
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42458
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42815
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43045
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43391
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43347
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43583
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43696
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43982
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43771
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43985
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44209
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44278
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44392
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44411
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44629
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44093
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44356
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44282
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 46140
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45891
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45823
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45586
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45584
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45729
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45591
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45361
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45323
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45140
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 45002
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44969
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44931
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44824
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44914
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44745
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44389
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43974
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44178
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44004
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43827
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43892
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43686
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43490
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43546
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43517
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43728
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43072
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43103
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42932
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42860
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42586
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43003
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42800
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43118
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42956
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43232
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42872
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43306
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42973
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43125
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43133
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43584
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43483
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43787
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43506
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43870
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43504
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43832
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43901
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44026
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44200
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44129
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41609
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41885
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41822
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41689
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41576
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41635
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41791
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41737
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41677
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41936
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42107
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42038
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42085
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 44045
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43704
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43657
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43681
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43603
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43479
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43644
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43577
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43720
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43620
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43651
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43186
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43435
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42936
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 43166
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42784
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42911
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42417
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42496
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42526
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42360
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41781
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41918
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41713
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41814
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41780
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41756
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41519
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41712
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41701
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41663
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41326
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41421
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41216
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40909
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40559
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40492
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40414
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40238
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40159
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39943
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39729
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40001
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40064
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39925
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40039
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40190
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40238
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40653
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40418
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40576
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40268
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40323
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38536
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38478
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38556
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38713
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38759
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38844
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38965
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39216
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39054
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39194
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39312
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39198
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39485
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39493
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39657
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40062
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40212
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40020
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40040
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40387
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40738
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40646
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40765
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40962
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40785
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41065
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41021
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41153
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40954
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41333
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41435
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41522
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41557
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41667
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41573
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41860
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41495
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41334
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41285
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41334
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41338
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40988
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41204
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42925
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42506
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42715
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42577
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42714
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42252
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42764
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42573
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42792
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42485
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42376
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42002
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42103
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41610
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41765
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41195
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41403
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41513
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41180
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41161
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40925
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40802
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40805
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40798
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40638
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40694
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40831
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40882
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40893
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40934
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41108
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40768
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41035
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41064
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41156
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40922
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41184
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41231
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40944
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41010
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41204
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41030
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41371
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41534
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41820
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41564
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41753
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41672
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41805
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41879
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42101
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41505
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41593
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39524
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39402
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38957
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39613
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39573
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39751
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39734
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40272
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40022
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40524
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40736
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41263
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40946
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41374
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41400
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41498
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41683
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42021
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41943
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42461
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42528
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42758
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42685
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42923
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42867
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42704
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42739
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42553
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42142
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42288
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42387
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42011
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41834
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41873
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41781
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41291
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41606
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41268
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41057
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41316
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41334
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40778
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40665
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42317
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42617
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42141
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42122
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42261
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41970
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 42072
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41760
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41917
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41658
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41946
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41947
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41632
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41755
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41671
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41508
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41608
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41428
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41329
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41266
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41292
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41154
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40743
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40856
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40766
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40498
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40740
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40855
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40695
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40509
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40648
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40552
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40410
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40605
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40894
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40645
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41157
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41243
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 41198
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40823
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40886
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40656
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40461
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40529
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40313
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40002
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39655
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39257
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38911
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38397
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38612
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38287
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37816
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 35848
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36228
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36257
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36506
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36431
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36354
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 35972
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36449
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36182
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 35976
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36038
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36512
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36161
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36523
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36509
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36816
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36503
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36942
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36647
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36928
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 36949
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37236
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37192
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37529
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37597
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37823
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37710
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37966
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37911
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37668
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37825
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38369
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37752
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38279
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38231
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39149
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39204
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39874
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39467
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38951
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38414
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38768
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38396
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40471
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40451
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 40039
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39636
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39790
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39675
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39373
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39532
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39172
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39206
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39198
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38887
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38980
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38451
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38399
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38336
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38163
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38184
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38284
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37939
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37695
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37722
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37545
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37529
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37526
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37658
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37748
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38065
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38523
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38493
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38758
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38782
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38761
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38903
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39118
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39111
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39045
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39107
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39535
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39375
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39717
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39718
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39991
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39619
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39756
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39727
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39668
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39460
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39808
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39500
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39618
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39393
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39204
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37480
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37748
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37911
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38044
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 37947
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38685
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38598
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39104
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 38920
# STREAM b'IHDR' 16 13
# STREAM b'tEXt' 41 57
# STREAM b'pHYs' 110 9
# STREAM b'IDAT' 131 39035

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 4 * n_rows))
fig.tight_layout(pad=4.0)
cmap = plt.get_cmap('viridis')

for i in range(11):
    row = i // n_cols
    col = i % n_cols
    ax = axes[row, col]
    
    # Calculando el error
    errors = np.array(data['pred_E_shifted'][i*150][0]) - np.array(data['true_E_shifted'][i][0])
    
    # Obtener los índices
    indices = range(len(errors))
    
    # Coloreando las barras basadas en el error
    colors = [cmap(abs(error)/max(abs(errors))) for error in errors]
    
    ax.bar(indices, errors, color=colors, label='Error')
    ax.set_title(f'Index {i}')
    ax.axhline(0, color='black', linewidth=0.8)  # Añadir una línea en y=0 para referencia
    ax.legend()

# Si el número total de subplots no es un múltiplo exacto de n_cols, ocultamos los subplots adicionales
if n_rows * n_cols > 11:
    for j in range(i+1, n_rows * n_cols):
        row = j // n_cols
        col = j % n_cols
        axes[row, col].axis('off')

plt.show()
# Out:
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/opt/conda/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/opt/conda/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# ## Distribución de los errores a lo largo de la ventana

# %%
import matplotlib.pyplot as plt
import numpy as np

# Suponiendo que data['pred_E_shifted'] y data['true_E_shifted'] tienen estructuras similares
# y contienen listas de numpy arrays para cada instancia

# Calculando el error para cada instancia y cada índice
errors = [np.array(pred[0]) - np.array(true[0]) for pred, true in zip(data['pred_E_shifted'], data['true_E_shifted'])]

# Calculando la media del error por índice
# Primero aseguramos que todos los arrays de error tienen la misma longitud
min_length = min(map(len, errors))  # Encontrando la longitud mínima por si acaso
errors_trimmed = [e[:min_length] for e in errors]  # Recortando para igualar longitudes
mean_errors = np.mean(errors_trimmed, axis=0)

# Graficando la media de errores
fig, ax = plt.subplots(figsize=(12, 6))
indices = np.arange(len(mean_errors))
cmap = plt.get_cmap('viridis')
colors = cmap(np.abs(mean_errors)/np.max(np.abs(mean_errors)))

ax.bar(indices, mean_errors, color=colors)
ax.set_title('Mean Error per Index')
ax.set_xlabel('Index')
ax.set_ylabel('Mean Error')
ax.axhline(0, color='black', linewidth=0.8)  # Línea en y=0 para referencia

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error
from scipy import stats

# Suponiendo que data['pred_E_shifted'] y data['true_E_shifted'] tienen estructuras similares
# y contienen listas de numpy arrays para cada instancia

# Calcular el RMSE para cada instancia y cada índice
rmse_per_instance = [np.sqrt(mean_squared_error(true[0], pred[0])) for pred, true in zip(data['pred_E_shifted'], data['true_E_shifted'])]

# Asumiendo que cada 'true' y 'pred' tienen la misma longitud, calcular el RMSE por índice
errors_squared = [(np.array(pred[0]) - np.array(true[0]))**2 for pred, true in zip(data['pred_E_shifted'], data['true_E_shifted'])]

# Igualando las longitudes
min_length = min(map(len, errors_squared))
errors_squared_trimmed = [e[:min_length] for e in errors_squared]

# Calculando el RMSE por índice
mean_errors_squared = np.mean(errors_squared_trimmed, axis=0)
rmse_per_index = np.sqrt(mean_errors_squared)

# Graficando el RMSE por índice
fig, ax = plt.subplots(figsize=(12, 6))
indices = np.arange(len(rmse_per_index))
ax.plot(indices, rmse_per_index, label='RMSE per Index', marker='o')

# Añadiendo una línea de tendencia
slope, intercept, r_value, p_value, std_err = stats.linregress(indices, rmse_per_index)
line = slope * indices + intercept
ax.plot(indices, line, 'r', label=f'Trend Line (slope={slope:.2f})')

ax.set_title('RMSE per Index with Trend Line')
ax.set_xlabel('Index')
ax.set_ylabel('RMSE')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Suponiendo que data['pred_E_shifted'] y data['true_E_shifted'] tienen estructuras similares
# y contienen listas de numpy arrays para cada instancia

# Calculando el error absoluto para cada instancia y cada índice
errors = [np.abs(np.array(pred[0]) - np.array(true[0])) for pred, true in zip(data['pred_E_shifted'], data['true_E_shifted'])]

# Calculando la media del error absoluto por índice
# Primero aseguramos que todos los arrays de error tienen la misma longitud
min_length = min(map(len, errors))  # Encontrando la longitud mínima por si acaso
errors_trimmed = [e[:min_length] for e in errors]  # Recortando para igualar longitudes
mean_errors = np.mean(errors_trimmed, axis=0)

# Graficando la media de errores con un diagrama de líneas
fig, ax = plt.subplots(figsize=(12, 6))
indices = np.arange(len(mean_errors))

ax.plot(indices, mean_errors, label='MAE per Index')
ax.set_title('Mean Absolute Error (MAE) per Index')
ax.set_xlabel('Index')
ax.set_ylabel('MAE')
ax.set_ylim(0, 30000)

# Añadiendo líneas verticales para marcar cada día
n_intervals_per_day = 96  # 24 horas * 4 intervalos por hora
for day in range(1, len(mean_errors) // n_intervals_per_day + 1):
    ax.axvline(n_intervals_per_day * day, color='grey', linestyle='--', linewidth=0.5, label=f'Day {day}' if day == 1 else None)

# Añadiendo leyenda para el primer día para evitar repetición en la leyenda
ax.legend()

plt.show()

# %%
import utilities

# %%
nombre_modelo = 'bcn_fno_15min_150-acc-sliding'

utilities.guardar_datos_en_csv(data, main_path, nombre_modelo)
# Out:
# [INFO] Guardando datos....
